# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("TelcoCustomerChurnClean.csv")

# %%
dataset.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  subscription  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    Multiple subscription  InternetService  OnlineSecurity  OnlineBackup  \
# 0                      1                0               0             2
# 1                      0                0               2             0
# 2                      0                0               2             2
# 3                      1                0               2             0
# 4                      0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# ...

# %%
sns.histplot(dataset['tenure'])
title = 'Distribution : ' + 'tenure'
plt.title(title)
# Out:
# Text(0.5, 1.0, 'Distribution : tenure')

# %%
sns.histplot(dataset['MonthlyCharges'])
title = 'Distribution : ' + 'MonthlyCharges'
plt.title(title)
# Out:
# Text(0.5, 1.0, 'Distribution : MonthlyCharges')

# %%
sns.histplot(dataset['TotalCharges'])
title = 'Distribution : ' + 'TotalCharges'
plt.title(title)
# Out:
# Text(0.5, 1.0, 'Distribution : TotalCharges')

# %%
corr_matrix = dataset.corr()
fig, ax = plt.subplots(figsize=(16, 16))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', ax=ax)
plt.show()

# %%
plt.figure(figsize=(20, 8))
sns.countplot(x="tenure", hue="Churn", data=dataset)
plt.legend(["No Churn", 'churn'])
plt.show()

# %%
fig = plt.subplots(figsize = (8,8))
ax = sns.boxplot(x = 'gender',y = 'tenure',data = dataset,hue = 'Churn');
plt.title('tenure vs ' + 'gender')
# Out:
# Text(0.5, 1.0, 'tenure vs gender')

# %%
fig = plt.subplots(figsize = (8,8))
ax = sns.boxplot(x = 'SeniorCitizen',y = 'tenure',data = dataset,hue = 'Churn');
plt.title('tenure vs ' + 'SeniorCitizen')
# Out:
# Text(0.5, 1.0, 'tenure vs SeniorCitizen')

# %%
fig = plt.subplots(figsize = (8,8))
ax = sns.boxplot(x = 'Partner',y = 'tenure',data = dataset,hue = 'Churn');
plt.title('tenure vs ' + 'Partner')
# Out:
# Text(0.5, 1.0, 'tenure vs Partner')

# %%
fig = plt.subplots(figsize = (8,8))
ax = sns.boxplot(x = 'Dependents',y = 'tenure',data = dataset,hue = 'Churn');
plt.title('tenure vs ' + 'Dependents')
# Out:
# Text(0.5, 1.0, 'tenure vs Dependents')
